# %%
import pandas
data=pandas.read_csv('Advertising.csv')
data
# Out:
#       No     TV  Radio  Newspaper  Sales
# 0      1  230.1   37.8       69.2   22.1
# 1      2   44.5   39.3       45.1   10.4
# 2      3   17.2   45.9       69.3    9.3
# 3      4  151.5   41.3       58.5   18.5
# 4      5  180.8   10.8       58.4   12.9
# ..   ...    ...    ...        ...    ...
# 195  196   38.2    3.7       13.8    7.6
# 196  197   94.2    4.9        8.1    9.7
# 197  198  177.0    9.3        6.4   12.8
# 198  199  283.6   42.0       66.2   25.5
# 199  200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
#Check empties
data.isnull().sum()
# Out:
# No           0
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
#Split to X-predictors and Y-predicted
array=data.values
array
X = array[:,1:4]#tv,radio,Newspaper
Y = array[:,4]#sales
Y
# Out:
# array([22.1, 10.4,  9.3, 18.5, 12.9,  7.2, 11.8, 13.2,  4.8, 10.6,  8.6,
#        17.4,  9.2,  9.7, 19. , 22.4, 12.5, 24.4, 11.3, 14.6, 18. , 12.5,
#         5.6, 15.5,  9.7, 12. , 15. , 15.9, 18.9, 10.5, 21.4, 11.9,  9.6,
#        17.4,  9.5, 12.8, 25.4, 14.7, 10.1, 21.5, 16.6, 17.1, 20.7, 12.9,
#         8.5, 14.9, 10.6, 23.2, 14.8,  9.7, 11.4, 10.7, 22.6, 21.2, 20.2,
#        23.7,  5.5, 13.2, 23.8, 18.4,  8.1, 24.2, 15.7, 14. , 18. ,  9.3,
#         9.5, 13.4, 18.9, 22.3, 18.3, 12.4,  8.8, 11. , 17. ,  8.7,  6.9,
#        14.2,  5.3, 11. , 11.8, 12.3, 11.3, 13.6, 21.7, 15.2, 12. , 16. ,
#        12.9, 16.7, 11.2,  7.3, 19.4, 22.2, 11.5, 16.9, 11.7, 15.5, 25.4,
#        17.2, 11.7, 23.8, 14.8, 14.7, 20.7, 19.2,  7.2,  8.7,  5.3, 19.8,
#        13.4, 21.8, 14.1, 15.9, 14.6, 12.6, 12.2,  9.4, 15.9,  6.6, 15.5,
#         7. , 11.6, 15.2, 19.7, 10.6,  6.6,  8.8, 24.7,  9.7,  1.6, 12.7,
#         5.7, 19.6, 10.8, 11.6,  9.5, 20.8,  9.6, 20.7, 10.9, 19.2, 20.1,
#        10.4, 11.4, 10.3, 13.2, 25.4, 10.9, 10.1, 16.1, 11.6, 16.6, 19. ,
#        15.6,  3.2, 15.3, 10.1,  7.3, 12.9, 14.4, 13.3, 14.9, 18. , 11.9,
#        11.9,  8. , 12.2, 17.1, 15. ,  8.4, 14.5,  7.6, 11.7, 11.5, 27. ,
#        20.2, 11.7, 11.8, 12.6, 10.5, 12.2,  8.7, 26.2, 17.6, 22.6, 10.3,
#        17.3, 15.9,  6.7, 10.8,  9.9,  5.9, 19.6, 17.3,  7.6,  9.7, 12.8,
#        25.5, 13.4])

# %%
from sklearn import  model_selection
X_train,X_test,Y_train,Y_test=model_selection.train_test_split(X,Y,test_size=0.30,random_state=42)

# %%
# select a model and train using training data

from sklearn.svm import SVR
from sklearn.tree  import DecisionTreeRegressor
model=DecisionTreeRegressor()
#fit training data into model
model.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor()

# %%
#test our model
from sklearn.metrics import r2_score
prediction=model.predict(X_test)
print("our model Predicted:",prediction)
print("Expected outcome:",Y_test)
# Out:
# our model Predicted: [19.  23.8 18.9  5.6 23.8 15.3 22.6 10.1 12.  16.6  8.5  8.6 11.7  3.2
#  10.1 12.9  5.6 17.3  9.7 19.8 18.9 15.3 10.8 23.8  9.9  8.7 22.6 12.2
#  10.6  4.8 11.4  9.9 23.8  9.3 15.9 23.8 10.4 18.9 12.4  6.7 11.6 12.6
#  10.4  9.9 12.   8.8  9.7 15.   9.7 11.8 13.6 12.6  5.6  5.6  8.8 11.2
#   9.9 24.4  6.6 11.4]
# Expected outcome: [16.9 22.4 21.4  7.3 24.7 12.6 22.3  8.4 11.5 14.9  9.5  8.7 11.9  5.3
#  10.3 11.7  5.5 16.6 11.3 18.9 19.7 12.5 10.9 22.2  9.3  8.1 21.7 13.4
#  10.6  5.7 10.6 11.3 23.7  8.7 16.1 20.7 11.6 20.8 11.9  6.9 11.  12.8
#  10.1  9.7 11.6  7.6 10.5 14.6 10.4 12.  14.6 11.7  7.2  6.6  9.4 11.
#  10.9 25.4  7.6 11.7]

# %%
print("score",r2_score(Y_test,prediction))
# Out:
# score 0.9477194478465631

# %%
expense=[[250,100,50]]
output=model.predict(expense)
print("Predicted Expenses: ", output)

#we can conclude that more spending on tv,followed by radion then little on newspaper
# Out:
# Predicted Expenses:  [25.4]

# %%
# Imports Regression Models
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression

# Create an Empty List and append all models, Give the Models an alias Name
# i.e we called KNeighborsRegressor()) alias KNR etc
models = []
models.append(('D Trees', DecisionTreeRegressor()))
models.append(('KNR', KNeighborsRegressor()))
models.append(('LR', LinearRegression()))
models.append(('Support Machines', SVR()))
models.append(('Random Forest', RandomForestRegressor()))
models.append(('Gradient Boosting', GradientBoostingRegressor()))


# Import Cross Validation and KFOLD
from sklearn.model_selection import cross_val_score, KFold
# Create a for loop so that each model is tested in turn
for name, model in models:
          # Here we do a 10 split K-FOLD
          kfold = KFold(n_splits = 10, random_state=42, shuffle=True)

          # We get the results for each Fold, Train and Test using the Folds
          cv_results = cross_val_score(model, X_train, Y_train, cv = kfold,
          scoring='r2')

          # Get the average of all Folds for current model in the loop
          print(name, ' Results:= ', cv_results.mean())
# Out:
# D Trees  Results:=  0.9159502977833416
# KNR  Results:=  0.8790725161630053
# LR  Results:=  0.8757671101319765
# Support Machines  Results:=  0.7366226480205218
# Random Forest  Results:=  0.9624367882525622
# Gradient Boosting  Results:=  0.9669264119443592
