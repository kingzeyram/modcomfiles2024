# %%
# Imports Classification Models


from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
#Train atleast 3 models and test them
#Train usinf 70% of your data test using 30%
#get the accuracy scores for comparison
#use your own values to get predictions

# %%
import pandas

data =pandas.read_csv('pima.csv')
data
# Out:
#      Children  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0           6      148             72             35        0  33.6
# 1           1       85             66             29        0  26.6
# 2           8      183             64              0        0  23.3
# 3           1       89             66             23       94  28.1
# 4           0      137             40             35      168  43.1
# ..        ...      ...            ...            ...      ...   ...
# 763        10      101             76             48      180  32.9
# 764         2      122             70             27        0  36.8
# 765         5      121             72             23      112  26.2
# 766         1      126             60              0        0  30.1
# 767         1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age       Outcome
# 0                       0.627   50      Diabetic
# 1                       0.351   31  Not Diabetic
# ...

# %%
#clean
data.isnull().sum()
# Out:
# Children                    0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#arrange
array=data.values
array
# Out:
# array([[6, 148, 72, ..., 0.627, 50, 'Diabetic'],
#        [1, 85, 66, ..., 0.351, 31, 'Not Diabetic'],
#        [8, 183, 64, ..., 0.672, 32, 'Diabetic'],
#        ...,
#        [5, 121, 72, ..., 0.245, 30, 'Not Diabetic'],
#        [1, 126, 60, ..., 0.349, 47, 'Diabetic'],
#        [1, 93, 70, ..., 0.315, 23, 'Not Diabetic']], dtype=object)

# %%
#features and outcomes
x=array[0:,0:8] #features
y=array[0:,-1]  #outcomes
y
# Out:
# array(['Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic',
#        'Diabetic', 'Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Diabetic', 'Diabetic',
#        'Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Diabetic', 'Diabetic', 'Diabetic', 'Not Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Not Diabetic', 'Diabetic',
#        'Not Diabetic', 'Not Diabetic', 'Diabetic', 'Not Diabetic',
# ...

# %%
#split our data further into training data (70%) and testing data(30%)
from sklearn import model_selection
X_Train,X_Test,Y_Train,Y_Test = model_selection.train_test_split(x,y,test_size=0.30,random_state=42)

# %%
#calculate accuracy score and print it
#Test our model
# select a model and train using training data
#model1
model1=KNeighborsClassifier()
#fit training data into model
model1.fit(X_Train,Y_Train)
prediction=model1.predict(X_Test)
print("our model Predicted:",prediction)
print("Expected outcome:",Y_Test)
# check model accuracy
from sklearn.metrics import accuracy_score
acc=accuracy_score(Y_Test,prediction)
score=accuracy_score(Y_Test,pred)
score
# Out:
# our model Predicted: ['Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Diabetic'
#  'Not Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic'
#  'Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic' 'Diabetic' 'Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic'
#  'Not Diabetic' 'Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic'
#  'Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic'
#  'Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic'
# ...

# %%
#Model2
model2=LogisticRegression()
#fit training data into model
model2.fit(X_Train,Y_Train)

prediction=model2.predict(X_Test)
print("our model Predicted:",prediction)
print("Expected outcome:",Y_Test)
acc=accuracy_score(Y_Test,prediction)
score=accuracy_score(Y_Test,pred)
score
# Out:
# our model Predicted: ['Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Diabetic'
#  'Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic'
#  'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Diabetic' 'Diabetic' 'Diabetic' 'Diabetic' 'Diabetic'
#  'Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic'
#  'Not Diabetic' 'Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic'
#  'Not Diabetic' 'Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic'
#  'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic'
# ...

# %%
#Model3
model3=LinearDiscriminantAnalysis()
#fit training data into model
model3.fit(X_Train,Y_Train)
prediction=model2.predict(X_Test)
print("our model Predicted:",prediction)
print("Expected outcome:",Y_Test)
acc=accuracy_score(Y_Test,prediction)
score=accuracy_score(Y_Test,pred)
score
# Out:
# our model Predicted: ['Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic' 'Diabetic'
#  'Diabetic' 'Not Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic'
#  'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Diabetic' 'Diabetic' 'Diabetic' 'Diabetic' 'Diabetic'
#  'Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic'
#  'Not Diabetic' 'Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic'
#  'Not Diabetic' 'Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic'
#  'Not Diabetic' 'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Diabetic'
#  'Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic' 'Not Diabetic'
# ...
