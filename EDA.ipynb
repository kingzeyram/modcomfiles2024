# %%
import pandas

# %%
data = pandas.read_csv('bank.csv')
data
# Out:
#       Loan_ID  Gender Married     Education Self_Employed  ApplicantIncome  \
# 0    LP001002    Male      No      Graduate            No             5849
# 1    LP001003    Male     Yes      Graduate            No             4583
# 2    LP001005    Male     Yes      Graduate           Yes             3000
# 3    LP001006    Male     Yes  Not Graduate            No             2583
# 4    LP001008    Male      No      Graduate            No             6000
# ..        ...     ...     ...           ...           ...              ...
# 609  LP002978  Female      No      Graduate            No             2900
# 610  LP002979    Male     Yes      Graduate            No             4106
# 611  LP002983    Male     Yes      Graduate            No             8072
# 612  LP002984    Male     Yes      Graduate            No             7583
# 613  LP002990  Female      No      Graduate           Yes             4583
#
#      CoapplicantIncome  LoanAmount Property_Area Loan_Status
# ...

# %%
data['Loan_ID']
# Out:
# 0      LP001002
# 1      LP001003
# 2      LP001005
# 3      LP001006
# 4      LP001008
#          ...
# 609    LP002978
# 610    LP002979
# 611    LP002983
# 612    LP002984
# 613    LP002990
# Name: Loan_ID, Length: 614, dtype: object

# %%
data.head(10)
# Out:
#     Loan_ID Gender Married     Education Self_Employed  ApplicantIncome  \
# 0  LP001002   Male      No      Graduate            No             5849
# 1  LP001003   Male     Yes      Graduate            No             4583
# 2  LP001005   Male     Yes      Graduate           Yes             3000
# 3  LP001006   Male     Yes  Not Graduate            No             2583
# 4  LP001008   Male      No      Graduate            No             6000
# 5  LP001011   Male     Yes      Graduate           Yes             5417
# 6  LP001013   Male     Yes  Not Graduate            No             2333
# 7  LP001014   Male     Yes      Graduate            No             3036
# 8  LP001018   Male     Yes      Graduate            No             4006
# 9  LP001020   Male     Yes      Graduate            No            12841
#
#    CoapplicantIncome  LoanAmount Property_Area Loan_Status
# 0                0.0         NaN         Urban           Y
# ...

# %%
data[['Loan_ID', 'Gender', 'Loan_Status']]
# Out:
#       Loan_ID  Gender Loan_Status
# 0    LP001002    Male           Y
# 1    LP001003    Male           N
# 2    LP001005    Male           Y
# 3    LP001006    Male           Y
# 4    LP001008    Male           Y
# ..        ...     ...         ...
# 609  LP002978  Female           Y
# 610  LP002979    Male           Y
# 611  LP002983    Male           Y
# 612  LP002984    Male           Y
# 613  LP002990  Female           N
#
# [614 rows x 3 columns]

# %%
data[['Loan_ID', 'Gender', 'Loan_Status']].head(10)
# Out:
#     Loan_ID Gender Loan_Status
# 0  LP001002   Male           Y
# 1  LP001003   Male           N
# 2  LP001005   Male           Y
# 3  LP001006   Male           Y
# 4  LP001008   Male           Y
# 5  LP001011   Male           Y
# 6  LP001013   Male           Y
# 7  LP001014   Male           N
# 8  LP001018   Male           Y
# 9  LP001020   Male           N

# %%
data[['Education', 'ApplicantIncome', 'LoanAmount']].tail(10)
# Out:
#         Education  ApplicantIncome  LoanAmount
# 604      Graduate            12000       496.0
# 605  Not Graduate             2400         NaN
# 606      Graduate             3400       173.0
# 607  Not Graduate             3987       157.0
# 608      Graduate             3232       108.0
# 609      Graduate             2900        71.0
# 610      Graduate             4106        40.0
# 611      Graduate             8072       253.0
# 612      Graduate             7583       187.0
# 613      Graduate             4583       133.0

# %%
data.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
data.head(3)
# Out:
#     Loan_ID Gender Married Education Self_Employed  ApplicantIncome  \
# 0  LP001002   Male      No  Graduate            No             5849
# 1  LP001003   Male     Yes  Graduate            No             4583
# 2  LP001005   Male     Yes  Graduate           Yes             3000
#
#    CoapplicantIncome  LoanAmount Property_Area Loan_Status
# 0                0.0         NaN         Urban           Y
# 1             1508.0       128.0         Rural           N
# 2                0.0        66.0         Urban           Y

# %%
data['Self_Employed'].fillna('Unknown', inplace=True)

# %%
data.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
average = data['LoanAmount'].mean()
average
# Out:
# 146.41216216216216

# %%
data['LoanAmount'].fillna(average, inplace=True)
# Out:
# /tmp/ipykernel_3708/2265595190.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['LoanAmount'].fillna(average, inplace=True)

# %%
data.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount
# count       614.000000         614.000000  614.000000
# mean       5403.459283        1621.245798  146.412162
# std        6109.041673        2926.248369   84.037468
# min         150.000000           0.000000    9.000000
# 25%        2877.500000           0.000000  100.250000
# 50%        3812.500000        1188.500000  129.000000
# 75%        5795.000000        2297.250000  164.750000
# max       81000.000000       41667.000000  700.000000

# %%
data[['ApplicantIncome', 'LoanAmount']].corr()
# Out:
#                  ApplicantIncome  LoanAmount
# ApplicantIncome          1.00000     0.56562
# LoanAmount               0.56562     1.00000

# %%
data[['ApplicantIncome', 'CoapplicantIncome']].corr()
# Out:
#                    ApplicantIncome  CoapplicantIncome
# ApplicantIncome           1.000000          -0.116605
# CoapplicantIncome        -0.116605           1.000000

# %%
data.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount
# count       614.000000         614.000000  614.000000
# mean       5403.459283        1621.245798  146.412162
# std        6109.041673        2926.248369   84.037468
# min         150.000000           0.000000    9.000000
# 25%        2877.500000           0.000000  100.250000
# 50%        3812.500000        1188.500000  129.000000
# 75%        5795.000000        2297.250000  164.750000
# max       81000.000000       41667.000000  700.000000

# %%
# mean
data['ApplicantIncome'].mean()
# Out:
# 5403.459283387622

# %%
# mean
data['CoapplicantIncome'].mean()
# Out:
# 1621.2457980271008

# %%
# mean
data['LoanAmount'].mean()
# Out:
# 146.41216216216216

# %%
# mean for the 1st 10
data['LoanAmount'].head(10).mean()
# Out:
# 163.8412162162162

# %%
# mean for the last 20
data['CoapplicantIncome'].tail(20).mean()
# Out:
# 2983.05

# %%
# check proportion of males and females
data.groupby('Gender').size()
# Out:
# Gender
# Female    125
# Male      489
# dtype: int64

# %%
# gender and married column
# check no. of both males amd females that are married  or not
data.groupby(['Gender', 'Married']).size()
# Out:
# Gender  Married
# Female  No          83
#         Yes         42
# Male    No         130
#         Yes        359
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-v0_8')

# %%
sns.countplot(x=data['Gender'], palette='Blues')
# Out:
# /tmp/ipykernel_3708/3574491366.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data['Gender'], palette='Blues')
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.barplot(x=data['Self_Employed'], y=data['LoanAmount'], palette='Blues')
plt.title('Distribution of males and females')
plt.xlabel('Self_Employed')
plt.ylabel('Loan')
# Out:
# /tmp/ipykernel_3708/2918063260.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=data['Self_Employed'], y=data['LoanAmount'], palette='Blues')
# Text(0, 0.5, 'Loan')

# %%
# swarm
sns.swarmplot(x='Gender', y='ApplicantIncome', data = data, palette='magma')
# Out:
# /tmp/ipykernel_3708/508836824.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x='Gender', y='ApplicantIncome', data = data, palette='magma')
# /home/user/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 31.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='Gender', ylabel='ApplicantIncome'>
# /home/user/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 53.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
# swarm
sns.swarmplot(x='Gender', y='ApplicantIncome', data = data, palette='magma', hue='Self_Employed')
# Out:
# /home/user/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 31.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='Gender', ylabel='ApplicantIncome'>
# /home/user/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 53.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/user/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 10.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# swarm
sns.swarmplot(x='Self_Employed', y='LoanAmount', data = data, palette='magma')
# Out:
# /tmp/ipykernel_3708/3953124866.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x='Self_Employed', y='LoanAmount', data = data, palette='magma')
# /home/user/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 22.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='Self_Employed', ylabel='LoanAmount'>
# /home/user/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 35.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# swarm
sns.swarmplot(x='LoanAmount', y='Self_Employed', data = data, palette='magma')
# Out:
# /tmp/ipykernel_3708/2950742142.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x='LoanAmount', y='Self_Employed', data = data, palette='magma')
# /home/user/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 25.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='LoanAmount', ylabel='Self_Employed'>
# /home/user/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 36.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# scatterplot
sns.scatterplot(x='LoanAmount', y='ApplicantIncome', data = data, palette='magma', hue='Gender')
# Out:
# <Axes: xlabel='LoanAmount', ylabel='ApplicantIncome'>

# %%
# scatterplot
sns.scatterplot(x='CoapplicantIncome', y='LoanAmount', data = data, palette='magma', hue='ApplicantIncome')
# Out:
# <Axes: xlabel='CoapplicantIncome', ylabel='LoanAmount'>

# %%
data.head()
# Out:
#     Loan_ID Gender Married     Education Self_Employed  ApplicantIncome  \
# 0  LP001002   Male      No      Graduate            No             5849
# 1  LP001003   Male     Yes      Graduate            No             4583
# 2  LP001005   Male     Yes      Graduate           Yes             3000
# 3  LP001006   Male     Yes  Not Graduate            No             2583
# 4  LP001008   Male      No      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount Property_Area Loan_Status
# 0                0.0  146.412162         Urban           Y
# 1             1508.0  128.000000         Rural           N
# 2                0.0   66.000000         Urban           Y
# 3             2358.0  120.000000         Urban           Y
# 4                0.0  141.000000         Urban           Y

# %%
# piechart
data.groupby('Property_Area').size().plot(kind='pie')
plt.show()

# %%
# piechart
data.groupby('Property_Area').size().plot(kind='pie', autopct="%1.1f%%")
plt.show()
