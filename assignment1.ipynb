# %%
import pandas

dataframe= pandas.read_csv('sales.csv')

# %%
dataframe.isnull().sum()
# Out:
# name          0
# sku           0
# category      0
# quantity      0
# unit price    0
# ext price     0
# date          0
# dtype: int64

# %%
avg= dataframe['unit price'].mean()

avg
# Out:
# 56.179629999999996

# %%
avg= dataframe['ext price'].mean()

avg
# Out:
# 579.8439000000002

# %%
Max= dataframe['ext price'].mean()

Max
# Out:
# 579.8439000000002

# %%
Min= dataframe['unit price'].mean()

Min
# Out:
# 56.179629999999996

# %%
Min= dataframe['ext price'].mean()

Min
# Out:
# 579.8439000000002

# %%
#13

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x=dataframe['category'])
# Out:
# <Axes: xlabel='category', ylabel='count'>

# %%
sns.scatterplot(x='category',y='ext price',data=dataframe, palette='magma')
# Out:
# /tmp/ipykernel_10880/702701751.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='category',y='ext price',data=dataframe, palette='magma')
# <Axes: xlabel='category', ylabel='ext price'>

# %%
sns.barplot(x='category', y='unit price',data=dataframe, palette='Blues')
# Out:
# /tmp/ipykernel_10880/1928913564.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='category', y='unit price',data=dataframe, palette='Blues')
# <Axes: xlabel='category', ylabel='unit price'>

# %%
sns.swarmplot(x='category',y='ext price',data=dataframe ,palette='magma' )
# Out:
# /tmp/ipykernel_10880/2576299787.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x='category',y='ext price',data=dataframe ,palette='magma' )
# <Axes: xlabel='category', ylabel='ext price'>
# /home/user/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 5.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/user/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 5.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
dataframe.groupby('category').size().plot(kind='pie',autopct="%1.1f%%")
plt.show()

# %%
#correlation

# %%
avg=dataframe['unit price'].head(200).mean()
avg
# Out:
# 57.027699999999996

# %%
sum=dataframe.groupby('category').size().sum()
sum
# Out:
# 1000

# %%
import pandas
dataframe= pandas.read_csv('sales.csv')

dataframe.groupby('category').size()
# Out:
# category
# Belt     196
# Shirt    404
# Shoes    400
# dtype: int64

# %%
sum=dataframe.groupby('category').size().sum
sum
# Out:
# <bound method Series.sum of category
# Belt     196
# Shirt    404
# Shoes    400
# dtype: int64>
